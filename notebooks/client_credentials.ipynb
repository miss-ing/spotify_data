# %%
from pathlib import Path
import sys
import pandas as pd
import numpy as np

# %%
project_root = Path("..").resolve()
sys.path.append(str(project_root))

# %%
from dotenv import load_dotenv
import os
from pathlib import Path
from spot.web_api import get_client_credentials, get_access_token

env_file = project_root/ "my_client_credentials.env"

load_dotenv(dotenv_path=env_file)

client_id = os.getenv('client_id')
client_secret = os.getenv("client_secret")

client_credentials = get_client_credentials(env_file )

print(client_credentials.keys())
# Out:
# dict_keys(['client_id', 'client_secret'])
