# %%
from pathlib import Path
import sys

# %%
project_root = Path("..").resolve()
sys.path.append(str(project_root))

# %%
from spot.load_sesh import sesh_jsons_to_pd, extract_track_uris
from spot.web_api import get_client_credentials, get_access_token, get_several_json

# %%
#FILE INPUTS:
spotify_data_dir = project_root
sesh_dir = Path(spotify_data_dir)/"Spotify Extended Streaming History"
env_path = Path(spotify_data_dir )/ "my_client_credentials.env"
output_dir = Path(spotify_data_dir)/"intermediate_data"

# %%
df = sesh_jsons_to_pd(sesh_dir)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 844972 entries, 0 to 1509
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   timestamp                844972 non-null  datetime64[ns, UTC]
#  1   platform                 844972 non-null  object
#  2   ms_played                844972 non-null  int64
#  3   conn_country             844972 non-null  object
#  4   ip_addr                  844972 non-null  object
#  5   track_name               844289 non-null  object
#  6   artist_name              844289 non-null  object
#  7   album_name               844289 non-null  object
#  8   track_uri                844289 non-null  object
#  9   episode_name             408 non-null     object
#  10  episode_show_name        408 non-null     object
#  11  episode_uri              408 non-null     object
#  12  audiobook_title          275 non-null     object
#  13  audiobook_uri            275 non-null     object
#  14  audiobook_chapter_uri    275 non-null     object
#  15  audiobook_chapter_title  269 non-null     object
#  16  reason_start             844972 non-null  object
#  17  reason_end               844972 non-null  object
#  18  shuffle                  844972 non-null  bool
#  19  skipped                  844972 non-null  bool
#  20  offline                  844972 non-null  bool
#  21  offline_timestamp        465418 non-null  float64
#  22  incognito_mode           844972 non-null  bool
# dtypes: bool(4), datetime64[ns, UTC](1), float64(1), int64(1), object(16)
# memory usage: 132.2+ MB

# %%
unique_track_uris= extract_track_uris(df)

# %%
# web_api 
client_credentials = get_client_credentials(env_path )

# %%
access_token = (get_access_token(client_credentials))

# %%
get_several_json(unique_track_uris, access_token, output_dir)
# Out:
# Saved info for 35379 tracks in track_uri_info.json
